# %% [markdown]
# <a href="https://colab.research.google.com/github/abhiram-04/Supermarket-sales-prediction-and-EDA/blob/main/Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/supermarket_sales.csv")
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
sum=df.describe()
sum['new price']=round(sum['Unit price'],2)
sum['new price']
# Out:
# count    1000.00
# mean       55.67
# std        26.49
# min        10.08
# 25%        32.88
# 50%        55.23
# 75%        77.94
# max        99.96
# Name: new price, dtype: float64

# %%
df['Branch'].nunique()
# Out:
# 3

# %%
df['Branch'].value_counts()
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: count, dtype: int64

# %%
df=df.drop("Branch", axis=1)
df=df.drop("cogs", axis=1)
df=df.drop("Customer type", axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   City                     1000 non-null   object
#  2   Gender                   1000 non-null   object
#  3   Product line             1000 non-null   object
#  4   Unit price               1000 non-null   float64
#  5   Quantity                 1000 non-null   int64
#  6   Tax 5%                   1000 non-null   float64
#  7   Total                    1000 non-null   float64
#  8   Date                     1000 non-null   object
#  9   Time                     1000 non-null   object
#  10  Payment                  1000 non-null   object
#  11  gross margin percentage  1000 non-null   float64
#  12  gross income             1000 non-null   float64
#  13  Rating                   1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# std      26.494628     2.923431    11.708825   245.885335
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# 25%                   4.761905      5.924875     5.50000
# 50%                   4.761905     12.088000     7.00000
# ...

# %%
df.shape
# Out:
# (1000, 14)

# %%
import seaborn as sns
'''sns.scatterplot(data=df, x='Product line', y='City',hue='Quantity')'''
pd.value_counts(df["Product line"]).plot(kind='bar')
# Out:
# <ipython-input-14-79836c328ca5>:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(df["Product line"]).plot(kind='bar')
# <Axes: xlabel='Product line'>

# %%
sns.pairplot(data=df,vars=['Quantity','gross income','Rating'], hue="City")

# %%
import matplotlib.pyplot as plt
plt.style.use("default")
plt.figure(figsize=(15,10))
sns.barplot(data=df,x="Product line", y="Quantity")
plt.title("Product line vs Quantity",fontsize=30)
plt.xlabel("Product line")
plt.ylabel("Quantity")
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#                          Unit price  Quantity    Tax 5%     Total  \
# Unit price                 1.000000  0.010778  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442
#
#                          gross margin percentage  gross income    Rating
# Unit price                                   NaN      0.633962 -0.008778
# Quantity                                     NaN      0.705510 -0.015815
# Tax 5%                                       NaN      1.000000 -0.036442
# Total                                        NaN      1.000000 -0.036442
# gross margin percentage                      NaN           NaN       NaN
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# Assuming 'df' is your DataFrame
# Identify columns with object (string) dtype
object_columns = df.select_dtypes(include=['object']).columns

# Apply LabelEncoder to each object column
label_encoders = {}
for col in object_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le  # Store the encoders for later use if needed

# Now proceed with your model training as before
y = df['Gender']
x = df.drop('Gender', axis=1)

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0, test_size=0.2)

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# Assuming 'df' is your DataFrame
# Encode all object (string) columns in the DataFrame
df = df.apply(LabelEncoder().fit_transform)

# Separate features (X) and target (y) - CORRECTED
x = df.drop('Gender', axis=1)  # Features are everything *except* Gender
y = df['Gender']  # Target is the Gender column

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=0)

# Initialize and train the KNN classifier
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train, y_train)

y_pred=knn.predict(X_test)  # Use X_test for prediction
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",knn.score(X_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.51      0.59      0.55       244
#            1       0.54      0.46      0.49       256
#
#     accuracy                           0.52       500
#    macro avg       0.52      0.52      0.52       500
# weighted avg       0.52      0.52      0.52       500
#
# Confusion Matrix:
#  [[144 100]
#  [139 117]]
# Training Score:
#  59.4

# %%
plt.plot(y_train,y_pred)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

df = df.apply(LabelEncoder().fit_transform)

x = df.drop('Gender', axis=1)
y = df['Gender']

# Split the dataset into training and testing sets - ENSURE CONSISTENCY
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=123)  # Adjust test_size as needed

dtree = DecisionTreeClassifier(max_depth=6, random_state=123,criterion='entropy')
dtree.fit(x_train,y_train)
y_pred=dtree.predict(x_test)
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",dtree.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.49      0.27      0.35       125
#            1       0.50      0.72      0.59       125
#
#     accuracy                           0.50       250
#    macro avg       0.49      0.50      0.47       250
# weighted avg       0.49      0.50      0.47       250
#
# Confusion Matrix:
#  [[34 91]
#  [35 90]]
# Training Score:
#  66.8

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.ensemble import RandomForestClassifier

df=df.apply(LabelEncoder().fit_transform)

x=df.drop('Gender',axis=1)
y=df['Gender']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=123)

rf=RandomForestClassifier(n_estimators=100,random_state=123)
rf.fit(x_train,y_train)

y_pred=rf.predict(x_test)
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",rf.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.54      0.54      0.54       125
#            1       0.54      0.53      0.53       125
#
#     accuracy                           0.54       250
#    macro avg       0.54      0.54      0.54       250
# weighted avg       0.54      0.54      0.54       250
#
# Confusion Matrix:
#  [[68 57]
#  [59 66]]
# Training Score:
#  100.0
